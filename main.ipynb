# %%
class Paragraph:

    def __init__(self, text):
        self.text = text

    def __str__(self):
        return self.text

# %%
def load_from_text(file):
    with open(file, 'r', encoding="UTF-8") as f:
        text = f.read()
    return [Paragraph(line) for line in text.split('\n')]

# %%
class Question:

    def __init__(self, question_text: str, answers: list, right_answer: str, quest_type: str):
        self.question_text = question_text
        self.answers = answers
        self.right_answer = right_answer
        self.quest_type = quest_type

    def __str__(self):
        return "Quest: "+ self.question_text + "\nAnswers:\n\t" + "\n\t".join(self.answers) + "\nОтвет:\t" + self.right_answer

# %%
def load_questions(paragraphs, quest_type, question_handler = None, answer_handler = None, right_answer_handler = None):
    is_question = False
    start_answer = False
    question = ""
    answers = []
    questions = []
    for i in range(len(paragraphs)):
        if paragraphs[i].text.startswith("/////"):
            break
        if len(paragraphs[i].text.strip()) > 0:
            if not is_question:
                question += paragraphs[i].text.strip() + "\n"
            else:
                start_answer = True
                answers.append(paragraphs[i].text.strip())
        else:
            if question == "":
                continue
            if not is_question:
                is_question = True
                start_answer = False
                question = question.strip()
            elif start_answer:
                if question_handler is not None:
                    question = question_handler(question)
                if answer_handler is not None:
                    new_answers = []
                    for answer in answers[:-1]:
                        new_answers.append(answer_handler(answer))
                    new_answers.append(answers[-1])
                    answers = new_answers
                if right_answer_handler is not None:
                    answers[-1] = right_answer_handler(answers[-1])
                questions.append(Question(question, answers[:-1], answers[-1], quest_type))
                question = ""
                answers = []
                is_question = False
                start_answer = False
    return questions

# %%
import docx

# %%
source = docx.Document("./source/Тест_Психология_последняя_версия (2).docx")
# Out:
# ---------------------------------------------------------------------------
# PackageNotFoundError                      Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 source = docx.Document("./source/Тест_Психология_последняя_версия (2).txt")
#
# File Z:\Projects\PyCharm\skif-test\venv\Lib\site-packages\docx\api.py:25, in Document(docx)
#      18 """
#      19 Return a |Document| object loaded from *docx*, where *docx* can be
#      20 either a path to a ``.docx`` file (a string) or a file-like object. If
#      21 *docx* is missing or ``None``, the built-in default document "template"
#      22 is loaded.
#      23 """
#      24 docx = _default_docx_path() if docx is None else docx
# ---> 25 document_part = Package.open(docx).main_document_part
#      26 if document_part.content_type != CT.WML_DOCUMENT_MAIN:
#      27     tmpl = "file '%s' is not a Word file, content type is '%s'"
#
# ...

# %%
questions = load_questions(source.paragraphs, "closed")
# Out:
# question: В сети Internet не существует следующей службы
# quest close
# answer: Служба телеконференций
# answer: Электронная почта
# answer: ICQ
# answer: Электронный журнал
# answer: IRC
# answer: Ответ: 4
# answer close
# space
# question: Укажите систему адресации, которая отсутствует в сети
# quest close
# answer: Система доменных имен
# answer: IP-адресация
# answer: Система русских имен
# answer: UP-адресация
# answer: Ответ: 3
# answer close
# space
# question: Гиперссылки на web - странице могут обеспечить переход …
# quest close
# answer: Только в пределах данной web – страницы
# answer: На любую web - страницу любого сервера Интернет
# answer: Только на web - страницы данного сервера
# answer: На любую web - страницу данного региона
# answer: Ответ: 2
# answer close
# space
# question: Браузеры являются …
# quest close
# answer: Серверами интернет
# answer: Антивирусными программами
# answer: Средством просмотра web-страниц
# answer: Трансляторами языка программирования
# ...

# %%
paragraphs = load_from_text("./source/Тест_Психология_последняя_версия (2).txt")
questions = load_questions(
    paragraphs,
    "closed",
    question_handler=lambda q: q.split("\t", 1)[-1],
    answer_handler=lambda a: a.split("\t", 1)[-1],
    right_answer_handler=lambda a: a.split(" ", 1)[-1]
)

# %%
for q in questions:
    print(q, end = "\n\n")
# Out:
# Quest: В сети Internet не существует следующей службы
# Answers:
# 	Служба телеконференций
# 	Электронная почта
# 	ICQ
# 	Электронный журнал
# 	IRC
# Ответ:	4
#
# Quest: Укажите систему адресации, которая отсутствует в сети
# Answers:
# 	Система доменных имен
# 	IP-адресация
# 	Система русских имен
# 	UP-адресация
# Ответ:	3
#
# Quest: Гиперссылки на web - странице могут обеспечить переход …
# Answers:
# 	Только в пределах данной web – страницы
# 	На любую web - страницу любого сервера Интернет
# 	Только на web - страницы данного сервера
# 	На любую web - страницу данного региона
# Ответ:	2
#
# Quest: Браузеры являются …
# Answers:
# 	Серверами интернет
# 	Антивирусными программами
# 	Средством просмотра web-страниц
# 	Трансляторами языка программирования
# Ответ:	3
#
# Quest: В качестве гипертекстовых ссылок можно использовать …
# Answers:
# 	Только слово
# 	Только картинку
# 	Слово, группу слов или картинку
# Ответ:	3
#
# Quest: Web-страница - это …
# Answers:
# ...
